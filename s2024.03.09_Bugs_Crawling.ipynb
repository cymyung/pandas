# %%
# 이 파일은 내가 3.9일 오전까지 한 파일, 에러가 나서 오후부터는 tt로 시작하는 강사 파일에서 작업
import pandas as pd
import requests
from bs4 import BeautifulSoup
from time import sleep

# %%
#1. 자주 사용하는 함수 정의
def bugs_row(tr):
    rank = tr.find('strong').text
    try:
        title = tr.find('p',{'class','title'}).find('a').text
    except:
        title = tr.find('p',{'class','title'}).find('span','').text
    artist = tr.find('p',{'class','artist'}).find('a').text
    try:
        album = tr.find('a',{'class','album'}).text
    except:
        album = tr.find('span',{'class','album'}).text
    row = [rank,title,artist,album]
    return row

# %%
url = 'https://music.bugs.co.kr/chart'
# response = headers + content(data, or text)
# response.headers : http 헤더를 사전(dict)형 자료로 조회해준
# response.content : http 본문을 data형(binary)형으로 조회, image, zip, hwp ...
# response.text : http 본문을 text(문자)형으로 조회, text/html
requests.get(url) # 200이 돌아오면 정상
# Out:
# <Response [200]>

# %%
response = requests.get(url)
response.headers
# Out:
# {'Date': 'Sat, 09 Mar 2024 02:14:55 GMT', 'X-Frame-Options': 'sameorigin', 'Strict-Transport-Security': 'max-age=15768000', 'Set-Cookie': 'SCOUTER=z4qd2sm6pdvi71; Max-Age=2147483647; Expires=Thu, 27-Mar-2092 05:29:02 GMT; Path=/, JSESSIONID=EF8ED61E50DC372C2406EAB619686856.s830; Path=/; Secure; HttpOnly', 'Cache-Control': 'no-cache, no-store', 'Pragma': 'no-cache', 'Expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'Content-Type': 'text/html;charset=UTF-8', 'Content-Language': 'ko,ko-kr', 'Vary': 'Accept-Encoding,User-Agent', 'Content-Encoding': 'gzip', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'P3P': 'CP="NON DSP COR ADMa OUR NOR FIN PRE GOV"', 'Keep-Alive': 'timeout=1, max=10000', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked'}

# %%
response.headers['Content-Type'] # response 본문의 data 종류를 알려줌
print(response.text[:260])
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# 	<!-- bgsweb-www913 -->
#
#
#
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta name="keywords" content="노래추천, 음악추천, 플레이리스트, essential, 에센셜, 스트리밍, 스밍, 뮤직PD, 노래듣기, 음악다운로드, 페이코" />

# %%
# 2. 웹문서내용(str,문자열)을 분석 가능한 객체(bs4.BeautifulSoup) 생성
# 3. find, find_all 메소드등을 이용하여 특정한 <tag> 블럭 조회
text = response.text 
html = BeautifulSoup(text,'html.parser')

# %%
# html내 table이 여러개 있을 수 있으니, 테이블 갯수를 본다.
len(html.find_all('table',{'class':'list'})) # {'class':'list'} 이걸 넣어서 한개임을 확인
# 이제 find_all은 필요없고, 갯수가 확인되었으므로 목록화된 {'class':'list'} 를 쓰면 된다.
# Out:
# 1

# %%
html = BeautifulSoup(text,'html.parser')
tr_list = html.find('table',{'class':'list'}).find('tbody').find_all('tr')
for tr in tr_list[:5]:
    rank = tr.find('strong').text
    print(rank)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
tr_list
# Out:
# [<tr albumid="4096123" artistid="20070472" multiartist="N" mvid="623018" rowtype="track" trackid="6233143">
#  <input name="_isStream" type="hidden" value="6233143">
#  <input name="_isDown" type="hidden" value="6233143">
#  <td class="check"><input buyminquality="T" disc_id="1" name="check" title="밤양갱" type="checkbox" value="6233143"/></td>
#  <td>
#  <div class="ranking">
#  <strong>1</strong>
#  <p class="change none"><em>0</em><span>변동없음</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/4096123?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="밤양갱 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40961/4096123.jpg?version=20240301015403.0"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/6233143?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
# ...

# %%
len(tr.find_all('strong')) #strong tag의 갯수가 몇개인지 확인
# Out:
# 1

# %%
tr = tr_list[0]
len(tr.find_all('a'))
# Out:
# 11

# %%
len(tr.find_all('p',{'class','title'}))
tr.find('p',{'class','title'}).find('a').text
# Out:
# '밤양갱'

# %%
tr=tr_list[0]
tr.find('p',{'class':'artist'}).find('a').text
# Out:
# '비비(BIBI)'

# %%
rows = []
for tr in tr_list[:5]:
    rank = tr.find('strong').text
    title = tr.find('p',{'class','title'}).find('a').text
    artist = tr.find('p',{'class','artist'}).find('a').text
    album = tr.find('a',{'class','album'}).text
    row = [rank,title,artist,album]
    rows.append(row)

# %%
rows
# Out:
# [['1', '밤양갱', '비비(BIBI)', '밤양갱'],
#  ['2', '첫 만남은 계획대로 되지 않아', 'TWS (투어스)', 'TWS 1st Mini Album ‘Sparkling Blue’'],
#  ['3', 'EASY', 'LE SSERAFIM (르세라핌)', 'EASY'],
#  ['4', '나는 아픈 건 딱 질색이니까', '(여자)아이들', '2'],
#  ['5', '홀씨', '아이유(IU)', 'The Winning']]

# %%
# 함수로 2번째에서 정의
rows = []
for tr in tr_list:
    bugs_row(tr)
    rows.append(row)

# %%
chart = pd.DataFrame(rows,columns = ['rank','title','artist','album'])
chart.set_index('rank',inplace = True)
chart
# Out:
#      title   artist        album
# rank
# 5       홀씨  아이유(IU)  The Winning
# 5       홀씨  아이유(IU)  The Winning
# 5       홀씨  아이유(IU)  The Winning
# 5       홀씨  아이유(IU)  The Winning
# 5       홀씨  아이유(IU)  The Winning
# ...    ...      ...          ...
# 5       홀씨  아이유(IU)  The Winning
# 5       홀씨  아이유(IU)  The Winning
# 5       홀씨  아이유(IU)  The Winning
# 5       홀씨  아이유(IU)  The Winning
# 5       홀씨  아이유(IU)  The Winning
#
# [100 rows x 3 columns]

# %%
# 과거날짜

# %%
year = 2024
month = 3
day = 8
date = f'{year:4}{month:0>2}{day:0>2}'
url = f'https://music.bugs.co.kr/chart/track/day/total?chartdate={date}'
print(url)

#밑에 부분은 위에서 짠 내용 복사해서 붙이면 해당 날짜의 순위를 구할 수 있다.
# Out:
# https://music.bugs.co.kr/chart/track/day/total?chartdate=20240308

# %%
year = 2024
month = 1
day = 5

f'{year:4}{month:0>2}{day:0>2}'
# Out:
# '20240105'

# %%
'%4d%02d%02d'%(year,month,day)
# Out:
# '20240105'

# %%
year = 2024
month = 1
for day in range(1,4):
    date = f'{year:4}{month:0>2}{day:0>2}'
    url = f'https://music.bugs.co.kr/chart/track/day/total?chartdate={date}'
    
    response = requests.get(url)
    text = response.text
    html = BeautifulSoup(text,'html.parser')
    tr_list = html.find('table',{'class':'list'}).find('tbody').find_all('tr')

    rows = []
    for tr in tr_list:
        bugs_row(tr)
        rows.append(row)
    chart = pd.DataFrame(rows,columns = ['rank','title','artist','album'])
    chart.set_index('rank',inplace = True)
    filename = f'csv/bugs_chart_{date}.csv'
    chart.to_csv(filename, encoding = 'utf-8-sig')
    sleep(3)          # -> dos 공격으로 인식하지 않도록 느리게 하기 위함

# %%
#에러가 난 경우(저작권 없는 곡)
date = '20180111'
url = f'https://music.bugs.co.kr/chart/track/day/total?chartdate={date}'

response = requests.get(url)
text = response.text
html = BeautifulSoup(text, 'html.parser')
tr_list = html.find('table',{'class','list'}).find('tbody').find_all('tr')

# %%
rank37 = tr_list[36]
rank38 = tr_list[37]

# %%
print(rank37.find('strong').text)
print(rank38.find('strong').text)
print('-'*40)
print(rank37.find('p',{'class','title'}))
print('-'*40)
print(rank38.find('p',{'class','title'}))
print('-'*40)
print(rank37.find('p',{'class','title'}).find('a').text)
print('-'*40)
print(rank38.find('p',{'class','title'}).find_all('span')[1])
print('or')
print(rank38.find('p',{'class','title'}).find('span','').text) # 속성이 없는 span 을 찾아라는 뜻
# Out:
# 37
# 38
# ----------------------------------------
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('4898930',true);
# " title="There's Nothing Holdin' Me Back">There's Nothing Holdin' Me Back</a>
# </p>
# ----------------------------------------
# <p adult_yn="N" class="title">
# <span class="badge permission">[권리없는 곡]</span>
# <span>My My My!</span>
# </p>
# ----------------------------------------
# There's Nothing Holdin' Me Back
# ----------------------------------------
# <span>My My My!</span>
# or
# My My My!

# %%
rank37.find('img').get('src').split('?')[0]
# Out:
# 'https://image.bugsm.co.kr/album/images/50/5673/567391.jpg'
